# %%
# Import pandas for data managing

import pandas as pd

# %%
# Load some data

data = pd.read_csv("iris.csv")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Describe data stats

data2 = pd.read_csv("movieprofit.csv")
data2.describe()
# Out:
#        Unnamed: 0      Rating    Duration  US_Gross_Million  \
# count   966.00000  966.000000  966.000000        966.000000
# mean    483.50000    6.814286  117.506211        156.158975
# std     279.00448    0.894383   21.615612        110.629617
# min       1.00000    3.300000   69.000000          0.010000
# 25%     242.25000    6.200000  101.250000         90.832500
# 50%     483.50000    6.800000  116.000000        129.245000
# 75%     724.75000    7.400000  130.000000        187.090000
# max     966.00000    9.200000  238.000000        936.660000
#
#        Worldwide_Gross_Million
# count               966.000000
# mean                410.140600
# std                 294.758791
# min                 176.600000
# 25%                 223.277500
# 50%                 309.345000
# 75%                 472.645000
# max                2847.400000

# %%
us_gross = data2["US_Gross_Million"]

# %%
us_gross
# Out:
# 0      760.51
# 1      858.37
# 2      659.33
# 3      936.66
# 4      678.82
#         ...
# 961     77.22
# 962    177.20
# 963    102.31
# 964    106.89
# 965     75.47
# Name: US_Gross_Million, Length: 966, dtype: float64

# %%
us_gross.describe()
# Out:
# count    966.000000
# mean     156.158975
# std      110.629617
# min        0.010000
# 25%       90.832500
# 50%      129.245000
# 75%      187.090000
# max      936.660000
# Name: US_Gross_Million, dtype: float64

# %%
data2.iloc[:, 2]
# Out:
# 0      2009
# 1      2019
# 2      1997
# 3      2015
# 4      2018
#        ...
# 961    2010
# 962    1982
# 963    1993
# 964    1999
# 965    2017
# Name: Year, Length: 966, dtype: object

# %%
data2.iloc[2, :]
# Out:
# Unnamed: 0                         3
# Title                        Titanic
# Year                            1997
# Genre                          Drama
# Rating                           7.9
# Duration                         194
# US_Gross_Million              659.33
# Worldwide_Gross_Million      2201.65
# Votes                      1,162,142
# Name: 2, dtype: object

# %%
data2.head()
# Out:
#    Unnamed: 0                                       Title  Year   Genre  \
# 0           1                                      Avatar  2009  Action
# 1           2                           Avengers: Endgame  2019  Action
# 2           3                                     Titanic  1997   Drama
# 3           4  Star Wars: Episode VII - The Force Awakens  2015  Action
# 4           5                      Avengers: Infinity War  2018  Action
#
#    Rating  Duration  US_Gross_Million  Worldwide_Gross_Million      Votes
# 0     7.8       162            760.51                  2847.40  1,236,962
# 1     8.4       181            858.37                  2797.50  1,108,641
# 2     7.9       194            659.33                  2201.65  1,162,142
# 3     7.8       138            936.66                  2069.52    925,551
# 4     8.4       149            678.82                  2048.36  1,062,517

# %%
# Searching data
data2.loc[data2['Genre'] == 'Comedy']
# Out:
#      Unnamed: 0                         Title  Year   Genre  Rating  Duration  \
# 161         162                    Mamma Mia!  2008  Comedy     6.5       108
# 170         171          The Hangover Part II  2011  Comedy     6.4       102
# 183         184                    Mei ren yu  2016  Comedy     6.2        94
# 186         187                           Ted  2012  Comedy     6.9       106
# 208         209              Meet the Fockers  2004  Comedy     6.3       115
# ..          ...                           ...   ...     ...     ...       ...
# 954         955  How to Lose a Guy in 10 Days  2003  Comedy     6.4       116
# 957         958        The 40 Year Old Virgin  2005  Comedy     7.1       116
# 960         961               The Descendants  2011  Comedy     7.3       115
# 962         963                       Tootsie  1982  Comedy     7.4       116
# 964         965                  Analyze This  1999  Comedy     6.7       103
#
# ...

# %%
# Visualization
import matplotlib.pyplot as plt

# %%
plt.scatter(data2["US_Gross_Million"], data2["Worldwide_Gross_Million"])

# %%
plt.scatter(data2["US_Gross_Million"], data2["Worldwide_Gross_Million"])

plt.title("This is my plot")
# Out:
# Text(0.5, 1.0, 'This is my plot')
