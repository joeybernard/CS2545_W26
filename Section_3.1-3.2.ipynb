# %% [markdown]
# ## Section 3.1, 3.2

# %%
import pandas as pd
import numpy as np

data = [15,14,13,16,17,14,14,15,12,6,20,14,13,14]

# %%
df = pd.DataFrame(data)

# %%
df.describe()
# Out:
#                0
# count  14.000000
# mean   14.071429
# std     3.049950
# min     6.000000
# 25%    13.250000
# 50%    14.000000
# 75%    15.000000
# max    20.000000
